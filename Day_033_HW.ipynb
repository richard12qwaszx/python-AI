# %% [markdown]
# ## 練習時間

# %% [markdown]
# 請觀看李宏毅教授以神奇寶貝進化 CP 值預測的範例，解說何謂機器學習與過擬合。並回答以下問題

# %% [markdown]
# [youtube](https://www.youtube.com/watch?v=fegAeph9UaA)

# %% [markdown]
# ### 1. 模型的泛化能力 (generalization) 是指什麼？
# 意思是我們的設計模組可以應對未來的數據，也就是可以被廣泛使用卻仍在我們模型範圍內，也就是他的適應性很好，這就是泛化。
# ### 2. 分類問題與回歸問題分別可用的目標函數有哪些？
# https://chih-sheng-huang821.medium.com/%E6%A9%9F%E5%99%A8-%E6%B7%B1%E5%BA%A6%E5%AD%B8%E7%BF%92-%E5%9F%BA%E7%A4%8E%E4%BB%8B%E7%B4%B9-%E6%90%8D%E5%A4%B1%E5%87%BD%E6%95%B8-loss-function-2dcac5ebb6cb
# https://bigdatafinance.tw/index.php/news/607-5
# 交叉熵(cross-entropy)
# 均方誤差
# ![image.png](attachment:52112535-5037-444c-a53c-031c9d6c3113.png)
# 平均絕對值誤差（也稱 L1 損失）
# ![image.png](attachment:ae2a7b63-1b4f-4075-8a53-c0dc29252d14.png)
