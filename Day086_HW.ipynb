# %% [markdown]
# ## Work
# 1. 試比較 save_best_only 與否的差異
# 2. 請僅存入將 save_weights_only 設定為 True, 並嘗試 reset ipynb 並將模型與權重重新建回並預測 x_test

# %%
import os
import keras

# Disable GPU
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
# Out:
# Using TensorFlow backend.
# C:\Users\Richard\anaconda3\envs\finlab\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\Richard\anaconda3\envs\finlab\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\Richard\anaconda3\envs\finlab\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\Richard\anaconda3\envs\finlab\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\Richard\anaconda3\envs\finlab\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\Richard\anaconda3\envs\finlab\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# C:\Users\Richard\anaconda3\envs\finlab\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\Richard\anaconda3\envs\finlab\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\Richard\anaconda3\envs\finlab\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\Richard\anaconda3\envs\finlab\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\Richard\anaconda3\envs\finlab\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\Richard\anaconda3\envs\finlab\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
train, test = keras.datasets.cifar10.load_data()

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = keras.utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# Preproc the inputs
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# Preprc the outputs
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
from keras.layers import BatchNormalization

"""
建立神經網路，並加入 BN layer
"""
def build_mlp(input_shape, output_units=10, num_neurons=[512, 256, 128]):
    input_layer = keras.layers.Input(input_shape)
    
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(input_layer)
            x = BatchNormalization()(x)
        else:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(x)
            x = BatchNormalization()(x)
    
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

# %%
## 超參數設定
LEARNING_RATE = 1e-3
EPOCHS = 50
BATCH_SIZE = 1024
MOMENTUM = 0.95

# %%
"""
# 載入 Callbacks, 並將監控目標設為 validation loss, 且只存最佳參數時的模型
"""
from keras.callbacks import ModelCheckpoint

model_ckpt = ModelCheckpoint(filepath="./tmp.h5",  #path to save 
                             monitor="val_loss",   #target to monitor
                             verbose=1,            #print information   
                             save_best_only=True)  #save bext checkpoint

# %%
model = build_mlp(input_shape=x_train.shape[1:])
model.summary()
optimizer = keras.optimizers.SGD(lr=LEARNING_RATE, nesterov=True, momentum=MOMENTUM)
model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

model.fit(x_train, y_train, 
          epochs=EPOCHS, 
          batch_size=BATCH_SIZE, 
          validation_data=(x_test, y_test), 
          shuffle=True,
          callbacks=[model_ckpt]
         )
model.save("final_model.h5")
model.save_weights("model_weights.h5")
# Collect results
train_loss = model.history.history["loss"]
valid_loss = model.history.history["val_loss"]
train_acc = model.history.history["acc"]
valid_acc = model.history.history["val_acc"]

pred_final = model.predict(x_test)
# Load back
model = keras.models.load_model("./tmp.h5")
pred_loadback = model.predict(x_test)
# Out:
# WARNING:tensorflow:From C:\Users\Richard\anaconda3\envs\finlab\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\Richard\anaconda3\envs\finlab\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From C:\Users\Richard\anaconda3\envs\finlab\lib\site-packages\keras\backend\tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From C:\Users\Richard\anaconda3\envs\finlab\lib\site-packages\keras\backend\tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# WARNING:tensorflow:From C:\Users\Richard\anaconda3\envs\finlab\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From C:\Users\Richard\anaconda3\envs\finlab\lib\site-packages\keras\backend\tensorflow_backend.py:3295: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From C:\Users\Richard\anaconda3\envs\finlab\lib\site-packages\tensorflow\python\ops\math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 4s 76us/step - loss: 2.2149 - acc: 0.2674 - val_loss: 2.0716 - val_acc: 0.3082
#
# Epoch 00001: val_loss improved from inf to 2.07162, saving model to ./tmp.h5
# Epoch 2/50
# 50000/50000 [==============================] - 3s 63us/step - loss: 1.7466 - acc: 0.3899 - val_loss: 1.8301 - val_acc: 0.3648
#
# Epoch 00002: val_loss improved from 2.07162 to 1.83011, saving model to ./tmp.h5
# Epoch 3/50
# 50000/50000 [==============================] - 3s 63us/step - loss: 1.6205 - acc: 0.4322 - val_loss: 1.6859 - val_acc: 0.4059
#
# Epoch 00003: val_loss improved from 1.83011 to 1.68592, saving model to ./tmp.h5
# Epoch 4/50
# 50000/50000 [==============================] - 3s 63us/step - loss: 1.5478 - acc: 0.4588 - val_loss: 1.6272 - val_acc: 0.4221
#
# Epoch 00004: val_loss improved from 1.68592 to 1.62722, saving model to ./tmp.h5
# Epoch 5/50
# 50000/50000 [==============================] - 3s 63us/step - loss: 1.4924 - acc: 0.4778 - val_loss: 1.5910 - val_acc: 0.4376
#
# Epoch 00005: val_loss improved from 1.62722 to 1.59101, saving model to ./tmp.h5
# Epoch 6/50
# 50000/50000 [==============================] - 3s 64us/step - loss: 1.4459 - acc: 0.4948 - val_loss: 1.5584 - val_acc: 0.4484
#
# Epoch 00006: val_loss improved from 1.59101 to 1.55838, saving model to ./tmp.h5
# Epoch 7/50
# 50000/50000 [==============================] - 3s 63us/step - loss: 1.4074 - acc: 0.5098 - val_loss: 1.5428 - val_acc: 0.4578
#
# Epoch 00007: val_loss improved from 1.55838 to 1.54284, saving model to ./tmp.h5
# Epoch 8/50
# 50000/50000 [==============================] - 3s 63us/step - loss: 1.3723 - acc: 0.5201 - val_loss: 1.5348 - val_acc: 0.4577
#
# Epoch 00008: val_loss improved from 1.54284 to 1.53478, saving model to ./tmp.h5
# Epoch 9/50
# 50000/50000 [==============================] - 3s 63us/step - loss: 1.3403 - acc: 0.5325 - val_loss: 1.5153 - val_acc: 0.4678
#
# Epoch 00009: val_loss improved from 1.53478 to 1.51529, saving model to ./tmp.h5
# Epoch 10/50
# 50000/50000 [==============================] - 3s 64us/step - loss: 1.3078 - acc: 0.5440 - val_loss: 1.5096 - val_acc: 0.4707
#
# Epoch 00010: val_loss improved from 1.51529 to 1.50964, saving model to ./tmp.h5
# Epoch 11/50
# 50000/50000 [==============================] - 3s 64us/step - loss: 1.2782 - acc: 0.5550 - val_loss: 1.4757 - val_acc: 0.4797
#
# Epoch 00011: val_loss improved from 1.50964 to 1.47567, saving model to ./tmp.h5
# Epoch 12/50
# 50000/50000 [==============================] - 3s 64us/step - loss: 1.2510 - acc: 0.5656 - val_loss: 1.4735 - val_acc: 0.4839
#
# Epoch 00012: val_loss improved from 1.47567 to 1.47353, saving model to ./tmp.h5
# Epoch 13/50
# 50000/50000 [==============================] - 3s 64us/step - loss: 1.2262 - acc: 0.5754 - val_loss: 1.4895 - val_acc: 0.4761
#
# Epoch 00013: val_loss did not improve from 1.47353
# Epoch 14/50
# 50000/50000 [==============================] - 3s 65us/step - loss: 1.2017 - acc: 0.5837 - val_loss: 1.4778 - val_acc: 0.4857
#
# Epoch 00014: val_loss did not improve from 1.47353
# Epoch 15/50
# 50000/50000 [==============================] - 3s 64us/step - loss: 1.1758 - acc: 0.5948 - val_loss: 1.4583 - val_acc: 0.4918
#
# Epoch 00015: val_loss improved from 1.47353 to 1.45833, saving model to ./tmp.h5
# Epoch 16/50
# 50000/50000 [==============================] - 3s 64us/step - loss: 1.1527 - acc: 0.6022 - val_loss: 1.4663 - val_acc: 0.4867
#
# Epoch 00016: val_loss did not improve from 1.45833
# Epoch 17/50
# 50000/50000 [==============================] - 3s 64us/step - loss: 1.1328 - acc: 0.6090 - val_loss: 1.4691 - val_acc: 0.4917
#
# Epoch 00017: val_loss did not improve from 1.45833
# Epoch 18/50
# 50000/50000 [==============================] - 3s 64us/step - loss: 1.1083 - acc: 0.6188 - val_loss: 1.4468 - val_acc: 0.4941
#
# Epoch 00018: val_loss improved from 1.45833 to 1.44684, saving model to ./tmp.h5
# Epoch 19/50
# 50000/50000 [==============================] - 3s 64us/step - loss: 1.0861 - acc: 0.6287 - val_loss: 1.4528 - val_acc: 0.4956
#
# Epoch 00019: val_loss did not improve from 1.44684
# Epoch 20/50
# 50000/50000 [==============================] - 3s 64us/step - loss: 1.0652 - acc: 0.6358 - val_loss: 1.4588 - val_acc: 0.4941
#
# Epoch 00020: val_loss did not improve from 1.44684
# Epoch 21/50
# 50000/50000 [==============================] - 3s 64us/step - loss: 1.0428 - acc: 0.6442 - val_loss: 1.4510 - val_acc: 0.4972
#
# Epoch 00021: val_loss did not improve from 1.44684
# Epoch 22/50
# 50000/50000 [==============================] - 3s 65us/step - loss: 1.0197 - acc: 0.6541 - val_loss: 1.4551 - val_acc: 0.4908
#
# Epoch 00022: val_loss did not improve from 1.44684
# Epoch 23/50
# 50000/50000 [==============================] - 3s 64us/step - loss: 1.0020 - acc: 0.6609 - val_loss: 1.4560 - val_acc: 0.4934
#
# Epoch 00023: val_loss did not improve from 1.44684
# Epoch 24/50
# 50000/50000 [==============================] - 3s 64us/step - loss: 0.9800 - acc: 0.6690 - val_loss: 1.4641 - val_acc: 0.4955
#
# Epoch 00024: val_loss did not improve from 1.44684
# Epoch 25/50
# 50000/50000 [==============================] - 3s 63us/step - loss: 0.9600 - acc: 0.6778 - val_loss: 1.4667 - val_acc: 0.4949
#
# Epoch 00025: val_loss did not improve from 1.44684
# Epoch 26/50
# 50000/50000 [==============================] - 3s 64us/step - loss: 0.9401 - acc: 0.6828 - val_loss: 1.4605 - val_acc: 0.4963
#
# Epoch 00026: val_loss did not improve from 1.44684
# Epoch 27/50
# 50000/50000 [==============================] - 3s 63us/step - loss: 0.9206 - acc: 0.6921 - val_loss: 1.4772 - val_acc: 0.4913
#
# Epoch 00027: val_loss did not improve from 1.44684
# Epoch 28/50
# 50000/50000 [==============================] - 3s 63us/step - loss: 0.8995 - acc: 0.6998 - val_loss: 1.4717 - val_acc: 0.4980
#
# Epoch 00028: val_loss did not improve from 1.44684
# Epoch 29/50
# 50000/50000 [==============================] - 3s 63us/step - loss: 0.8794 - acc: 0.7093 - val_loss: 1.4728 - val_acc: 0.4971
#
# Epoch 00029: val_loss did not improve from 1.44684
# Epoch 30/50
# 50000/50000 [==============================] - 3s 63us/step - loss: 0.8604 - acc: 0.7160 - val_loss: 1.5164 - val_acc: 0.4799
#
# Epoch 00030: val_loss did not improve from 1.44684
# Epoch 31/50
# 50000/50000 [==============================] - 3s 63us/step - loss: 0.8404 - acc: 0.7244 - val_loss: 1.5111 - val_acc: 0.4953
#
# Epoch 00031: val_loss did not improve from 1.44684
# Epoch 32/50
# 50000/50000 [==============================] - 3s 63us/step - loss: 0.8230 - acc: 0.7305 - val_loss: 1.4955 - val_acc: 0.4994
#
# Epoch 00032: val_loss did not improve from 1.44684
# Epoch 33/50
# 50000/50000 [==============================] - 3s 63us/step - loss: 0.8018 - acc: 0.7396 - val_loss: 1.5051 - val_acc: 0.4981
#
# Epoch 00033: val_loss did not improve from 1.44684
# Epoch 34/50
# 50000/50000 [==============================] - 3s 63us/step - loss: 0.7839 - acc: 0.7458 - val_loss: 1.4981 - val_acc: 0.4992
#
# Epoch 00034: val_loss did not improve from 1.44684
# Epoch 35/50
# 50000/50000 [==============================] - 3s 63us/step - loss: 0.7651 - acc: 0.7535 - val_loss: 1.5188 - val_acc: 0.5017
#
# Epoch 00035: val_loss did not improve from 1.44684
# Epoch 36/50
# 50000/50000 [==============================] - 3s 63us/step - loss: 0.7458 - acc: 0.7610 - val_loss: 1.5347 - val_acc: 0.4948
#
# Epoch 00036: val_loss did not improve from 1.44684
# Epoch 37/50
# 50000/50000 [==============================] - 3s 63us/step - loss: 0.7267 - acc: 0.7675 - val_loss: 1.5397 - val_acc: 0.4935
#
# Epoch 00037: val_loss did not improve from 1.44684
# Epoch 38/50
# 50000/50000 [==============================] - 3s 63us/step - loss: 0.7093 - acc: 0.7748 - val_loss: 1.5460 - val_acc: 0.4944
#
# Epoch 00038: val_loss did not improve from 1.44684
# Epoch 39/50
# 50000/50000 [==============================] - 3s 63us/step - loss: 0.6899 - acc: 0.7827 - val_loss: 1.5645 - val_acc: 0.4958
#
# Epoch 00039: val_loss did not improve from 1.44684
# Epoch 40/50
# 50000/50000 [==============================] - 3s 63us/step - loss: 0.6724 - acc: 0.7882 - val_loss: 1.5709 - val_acc: 0.4935
#
# Epoch 00040: val_loss did not improve from 1.44684
# Epoch 41/50
# 50000/50000 [==============================] - 3s 63us/step - loss: 0.6546 - acc: 0.7967 - val_loss: 1.5932 - val_acc: 0.4942
#
# Epoch 00041: val_loss did not improve from 1.44684
# Epoch 42/50
# 50000/50000 [==============================] - 3s 63us/step - loss: 0.6371 - acc: 0.8042 - val_loss: 1.5898 - val_acc: 0.4911
#
# Epoch 00042: val_loss did not improve from 1.44684
# Epoch 43/50
# 50000/50000 [==============================] - 3s 63us/step - loss: 0.6189 - acc: 0.8102 - val_loss: 1.5904 - val_acc: 0.4936
#
# Epoch 00043: val_loss did not improve from 1.44684
# Epoch 44/50
# 50000/50000 [==============================] - 3s 63us/step - loss: 0.6020 - acc: 0.8177 - val_loss: 1.5992 - val_acc: 0.4979
#
# Epoch 00044: val_loss did not improve from 1.44684
# Epoch 45/50
# 50000/50000 [==============================] - 3s 63us/step - loss: 0.5841 - acc: 0.8236 - val_loss: 1.6422 - val_acc: 0.4924
#
# Epoch 00045: val_loss did not improve from 1.44684
# Epoch 46/50
# 50000/50000 [==============================] - 3s 63us/step - loss: 0.5684 - acc: 0.8315 - val_loss: 1.6445 - val_acc: 0.4925
#
# Epoch 00046: val_loss did not improve from 1.44684
# Epoch 47/50
# 50000/50000 [==============================] - 3s 63us/step - loss: 0.5503 - acc: 0.8377 - val_loss: 1.6382 - val_acc: 0.4891
#
# Epoch 00047: val_loss did not improve from 1.44684
# Epoch 48/50
# 50000/50000 [==============================] - 3s 63us/step - loss: 0.5324 - acc: 0.8458 - val_loss: 1.6535 - val_acc: 0.4960
#
# Epoch 00048: val_loss did not improve from 1.44684
# Epoch 49/50
# 50000/50000 [==============================] - 3s 63us/step - loss: 0.5166 - acc: 0.8527 - val_loss: 1.6572 - val_acc: 0.4920
#
# Epoch 00049: val_loss did not improve from 1.44684
# Epoch 50/50
# 50000/50000 [==============================] - 3s 62us/step - loss: 0.5014 - acc: 0.8561 - val_loss: 1.6990 - val_acc: 0.4913
#
# Epoch 00050: val_loss did not improve from 1.44684

# %%
from sklearn.metrics import accuracy_score

final_model_acc = accuracy_score(y_true=y_test.argmax(axis=-1), y_pred=pred_final.argmax(axis=-1))
loadback_acc = accuracy_score(y_true=y_test.argmax(axis=-1), y_pred=pred_loadback.argmax(axis=-1))

print("Accuracy of final weights: %.3f" % final_model_acc)
print("Accuracy of best weights: %.3f" % loadback_acc)
# Out:
# Accuracy of final weights: 0.491
# Accuracy of best weights: 0.494

# %%
new_model = build_mlp(input_shape=x_train.shape[1:])
new_model_pred = new_model.predict(x_test)
new_model_acc = accuracy_score(y_true=y_test.argmax(axis=-1), y_pred=new_model_pred.argmax(axis=-1))
print("Accuracy of best weights: %.3f" % new_model_acc)

new_model.load_weights("./model_weights.h5")
new_model_pred = new_model.predict(x_test)
new_model_loadback_acc = accuracy_score(y_true=y_test.argmax(axis=-1), y_pred=new_model_pred.argmax(axis=-1))
print("Accuracy of best weights: %.3f" % new_model_loadback_acc)
# Out:
# Accuracy of best weights: 0.126
# Accuracy of best weights: 0.491
