# %% [markdown]
# ## Work
# 1. 試比較 save_best_only 與否的差異
# 2. 請僅存入將 save_weights_only 設定為 True, 並嘗試 reset ipynb 並將模型與權重重新建回並預測 x_test

# %%
import os
import keras

# Disable GPU
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
# Out:
# Using TensorFlow backend.
# C:\Users\Richard\anaconda3\envs\tensorflowgpu\lib\site-packages\tensorflow\python\framework\dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\Richard\anaconda3\envs\tensorflowgpu\lib\site-packages\tensorflow\python\framework\dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\Richard\anaconda3\envs\tensorflowgpu\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\Richard\anaconda3\envs\tensorflowgpu\lib\site-packages\tensorflow\python\framework\dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\Richard\anaconda3\envs\tensorflowgpu\lib\site-packages\tensorflow\python\framework\dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\Richard\anaconda3\envs\tensorflowgpu\lib\site-packages\tensorflow\python\framework\dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
train, test = keras.datasets.cifar10.load_data()

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = keras.utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# Preproc the inputs
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# Preprc the outputs
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
from keras.layers import BatchNormalization

"""
建立神經網路，並加入 BN layer
"""
def build_mlp(input_shape, output_units=10, num_neurons=[512, 256, 128]):
    input_layer = keras.layers.Input(input_shape)
    
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(input_layer)
            x = BatchNormalization()(x)
        else:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(x)
            x = BatchNormalization()(x)
    
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

# %%
## 超參數設定
LEARNING_RATE = 1e-3
EPOCHS = 50
BATCH_SIZE = 1024
MOMENTUM = 0.95

# %%
"""
# 載入 Callbacks, 並將監控目標設為 validation loss, 且只存最佳參數時的模型
"""
from keras.callbacks import ModelCheckpoint

model_ckpt = ModelCheckpoint(filepath="./tmp.h5",  #path to save 
                             monitor="val_loss",   #target to monitor
                             verbose=1,            #print information   
                             save_best_only=True)  #save bext checkpoint

# %%
model = build_mlp(input_shape=x_train.shape[1:])
model.summary()
optimizer = keras.optimizers.SGD(lr=LEARNING_RATE, nesterov=True, momentum=MOMENTUM)
model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

model.fit(x_train, y_train, 
          epochs=EPOCHS, 
          batch_size=BATCH_SIZE, 
          validation_data=(x_test, y_test), 
          shuffle=True,
          callbacks=[model_ckpt]
         )

# Collect results
train_loss = model.history.history["loss"]
valid_loss = model.history.history["val_loss"]
train_acc = model.history.history["acc"]
valid_acc = model.history.history["val_acc"]

# Load back
model = keras.models.load_model("./tmp.h5")
loss_loadback, acc_loadback = model.evaluate(x_test, y_test)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 3s 70us/step - loss: 2.2211 - acc: 0.2718 - val_loss: 2.0725 - val_acc: 0.3119
#
# Epoch 00001: val_loss improved from inf to 2.07250, saving model to ./tmp.h5
# Epoch 2/50
# 50000/50000 [==============================] - 2s 33us/step - loss: 1.7379 - acc: 0.3941 - val_loss: 1.8266 - val_acc: 0.3704
#
# Epoch 00002: val_loss improved from 2.07250 to 1.82656, saving model to ./tmp.h5
# Epoch 3/50
# 50000/50000 [==============================] - 2s 33us/step - loss: 1.6185 - acc: 0.4333 - val_loss: 1.6978 - val_acc: 0.4093
#
# Epoch 00003: val_loss improved from 1.82656 to 1.69778, saving model to ./tmp.h5
# Epoch 4/50
# 50000/50000 [==============================] - 2s 33us/step - loss: 1.5476 - acc: 0.4579 - val_loss: 1.6331 - val_acc: 0.4228
#
# Epoch 00004: val_loss improved from 1.69778 to 1.63308, saving model to ./tmp.h5
# Epoch 5/50
# 50000/50000 [==============================] - 2s 32us/step - loss: 1.4944 - acc: 0.4785 - val_loss: 1.6057 - val_acc: 0.4318
#
# Epoch 00005: val_loss improved from 1.63308 to 1.60565, saving model to ./tmp.h5
# Epoch 6/50
# 50000/50000 [==============================] - 2s 32us/step - loss: 1.4493 - acc: 0.4935 - val_loss: 1.5672 - val_acc: 0.4478
#
# Epoch 00006: val_loss improved from 1.60565 to 1.56722, saving model to ./tmp.h5
# Epoch 7/50
# 50000/50000 [==============================] - 2s 32us/step - loss: 1.4084 - acc: 0.5084 - val_loss: 1.5501 - val_acc: 0.4514
#
# Epoch 00007: val_loss improved from 1.56722 to 1.55011, saving model to ./tmp.h5
# Epoch 8/50
# 50000/50000 [==============================] - 2s 33us/step - loss: 1.3732 - acc: 0.5216 - val_loss: 1.5373 - val_acc: 0.4589
#
# Epoch 00008: val_loss improved from 1.55011 to 1.53734, saving model to ./tmp.h5
# Epoch 9/50
# 50000/50000 [==============================] - 2s 33us/step - loss: 1.3393 - acc: 0.5337 - val_loss: 1.5195 - val_acc: 0.4613
#
# Epoch 00009: val_loss improved from 1.53734 to 1.51953, saving model to ./tmp.h5
# Epoch 10/50
# 50000/50000 [==============================] - 2s 33us/step - loss: 1.3092 - acc: 0.5456 - val_loss: 1.5097 - val_acc: 0.4651
#
# Epoch 00010: val_loss improved from 1.51953 to 1.50968, saving model to ./tmp.h5
# Epoch 11/50
# 50000/50000 [==============================] - 2s 32us/step - loss: 1.2812 - acc: 0.5558 - val_loss: 1.4936 - val_acc: 0.4750
#
# Epoch 00011: val_loss improved from 1.50968 to 1.49365, saving model to ./tmp.h5
# Epoch 12/50
# 50000/50000 [==============================] - 2s 32us/step - loss: 1.2535 - acc: 0.5654 - val_loss: 1.5061 - val_acc: 0.4716
#
# Epoch 00012: val_loss did not improve from 1.49365
# Epoch 13/50
# 50000/50000 [==============================] - 2s 32us/step - loss: 1.2257 - acc: 0.5773 - val_loss: 1.4793 - val_acc: 0.4768
#
# Epoch 00013: val_loss improved from 1.49365 to 1.47931, saving model to ./tmp.h5
# Epoch 14/50
# 50000/50000 [==============================] - 2s 32us/step - loss: 1.2007 - acc: 0.5867 - val_loss: 1.4911 - val_acc: 0.4747
#
# Epoch 00014: val_loss did not improve from 1.47931
# Epoch 15/50
# 50000/50000 [==============================] - 2s 32us/step - loss: 1.1770 - acc: 0.5950 - val_loss: 1.4691 - val_acc: 0.4814
#
# Epoch 00015: val_loss improved from 1.47931 to 1.46913, saving model to ./tmp.h5
# Epoch 16/50
# 50000/50000 [==============================] - 2s 33us/step - loss: 1.1520 - acc: 0.6041 - val_loss: 1.4713 - val_acc: 0.4818
#
# Epoch 00016: val_loss did not improve from 1.46913
# Epoch 17/50
# 50000/50000 [==============================] - 2s 33us/step - loss: 1.1287 - acc: 0.6141 - val_loss: 1.4651 - val_acc: 0.4842
#
# Epoch 00017: val_loss improved from 1.46913 to 1.46512, saving model to ./tmp.h5
# Epoch 18/50
# 50000/50000 [==============================] - 2s 33us/step - loss: 1.1084 - acc: 0.6210 - val_loss: 1.4792 - val_acc: 0.4816
#
# Epoch 00018: val_loss did not improve from 1.46512
# Epoch 19/50
# 50000/50000 [==============================] - 2s 32us/step - loss: 1.0828 - acc: 0.6291 - val_loss: 1.4577 - val_acc: 0.4916
#
# Epoch 00019: val_loss improved from 1.46512 to 1.45768, saving model to ./tmp.h5
# Epoch 20/50
# 50000/50000 [==============================] - 2s 32us/step - loss: 1.0615 - acc: 0.6397 - val_loss: 1.4679 - val_acc: 0.4902
#
# Epoch 00020: val_loss did not improve from 1.45768
# Epoch 21/50
# 50000/50000 [==============================] - 2s 32us/step - loss: 1.0406 - acc: 0.6460 - val_loss: 1.4586 - val_acc: 0.4872
#
# Epoch 00021: val_loss did not improve from 1.45768
# Epoch 22/50
# 50000/50000 [==============================] - 2s 32us/step - loss: 1.0181 - acc: 0.6550 - val_loss: 1.4603 - val_acc: 0.4918
#
# Epoch 00022: val_loss did not improve from 1.45768
# Epoch 23/50
# 50000/50000 [==============================] - 2s 33us/step - loss: 0.9961 - acc: 0.6646 - val_loss: 1.4632 - val_acc: 0.4864
#
# Epoch 00023: val_loss did not improve from 1.45768
# Epoch 24/50
# 50000/50000 [==============================] - 2s 32us/step - loss: 0.9762 - acc: 0.6709 - val_loss: 1.4893 - val_acc: 0.4892
#
# Epoch 00024: val_loss did not improve from 1.45768
# Epoch 25/50
# 50000/50000 [==============================] - 2s 33us/step - loss: 0.9547 - acc: 0.6799 - val_loss: 1.4707 - val_acc: 0.4894
#
# Epoch 00025: val_loss did not improve from 1.45768
# Epoch 26/50
# 50000/50000 [==============================] - 2s 33us/step - loss: 0.9363 - acc: 0.6856 - val_loss: 1.4751 - val_acc: 0.4927
#
# Epoch 00026: val_loss did not improve from 1.45768
# Epoch 27/50
# 50000/50000 [==============================] - 2s 33us/step - loss: 0.9160 - acc: 0.6946 - val_loss: 1.4786 - val_acc: 0.4841
#
# Epoch 00027: val_loss did not improve from 1.45768
# Epoch 28/50
# 50000/50000 [==============================] - 2s 32us/step - loss: 0.8946 - acc: 0.7026 - val_loss: 1.4877 - val_acc: 0.4917
#
# Epoch 00028: val_loss did not improve from 1.45768
# Epoch 29/50
# 50000/50000 [==============================] - 2s 33us/step - loss: 0.8747 - acc: 0.7104 - val_loss: 1.5015 - val_acc: 0.4835
#
# Epoch 00029: val_loss did not improve from 1.45768
# Epoch 30/50
# 50000/50000 [==============================] - 2s 33us/step - loss: 0.8523 - acc: 0.7195 - val_loss: 1.4971 - val_acc: 0.4922
#
# Epoch 00030: val_loss did not improve from 1.45768
# Epoch 31/50
# 50000/50000 [==============================] - 2s 33us/step - loss: 0.8342 - acc: 0.7275 - val_loss: 1.5071 - val_acc: 0.4883
#
# Epoch 00031: val_loss did not improve from 1.45768
# Epoch 32/50
# 50000/50000 [==============================] - 2s 33us/step - loss: 0.8159 - acc: 0.7331 - val_loss: 1.5023 - val_acc: 0.4924
#
# Epoch 00032: val_loss did not improve from 1.45768
# Epoch 33/50
# 50000/50000 [==============================] - 2s 33us/step - loss: 0.7947 - acc: 0.7426 - val_loss: 1.5090 - val_acc: 0.4928
#
# Epoch 00033: val_loss did not improve from 1.45768
# Epoch 34/50
# 50000/50000 [==============================] - 2s 33us/step - loss: 0.7756 - acc: 0.7498 - val_loss: 1.5149 - val_acc: 0.4930
#
# Epoch 00034: val_loss did not improve from 1.45768
# Epoch 35/50
# 50000/50000 [==============================] - 2s 33us/step - loss: 0.7565 - acc: 0.7581 - val_loss: 1.5261 - val_acc: 0.4928
#
# Epoch 00035: val_loss did not improve from 1.45768
# Epoch 36/50
# 50000/50000 [==============================] - 2s 33us/step - loss: 0.7378 - acc: 0.7644 - val_loss: 1.5423 - val_acc: 0.4887
#
# Epoch 00036: val_loss did not improve from 1.45768
# Epoch 37/50
# 50000/50000 [==============================] - 2s 33us/step - loss: 0.7185 - acc: 0.7728 - val_loss: 1.5525 - val_acc: 0.4961
#
# Epoch 00037: val_loss did not improve from 1.45768
# Epoch 38/50
# 50000/50000 [==============================] - 2s 32us/step - loss: 0.7007 - acc: 0.7786 - val_loss: 1.5637 - val_acc: 0.4883
#
# Epoch 00038: val_loss did not improve from 1.45768
# Epoch 39/50
# 50000/50000 [==============================] - 2s 33us/step - loss: 0.6819 - acc: 0.7864 - val_loss: 1.5742 - val_acc: 0.4926
#
# Epoch 00039: val_loss did not improve from 1.45768
# Epoch 40/50
# 50000/50000 [==============================] - 2s 34us/step - loss: 0.6649 - acc: 0.7928 - val_loss: 1.5699 - val_acc: 0.4916
#
# Epoch 00040: val_loss did not improve from 1.45768
# Epoch 41/50
# 50000/50000 [==============================] - 2s 33us/step - loss: 0.6437 - acc: 0.8031 - val_loss: 1.5740 - val_acc: 0.4876
#
# Epoch 00041: val_loss did not improve from 1.45768
# Epoch 42/50
# 50000/50000 [==============================] - 2s 33us/step - loss: 0.6273 - acc: 0.8080 - val_loss: 1.5784 - val_acc: 0.4912
#
# Epoch 00042: val_loss did not improve from 1.45768
# Epoch 43/50
# 50000/50000 [==============================] - 2s 34us/step - loss: 0.6105 - acc: 0.8145 - val_loss: 1.6316 - val_acc: 0.4870
#
# Epoch 00043: val_loss did not improve from 1.45768
# Epoch 44/50
# 50000/50000 [==============================] - 2s 33us/step - loss: 0.5919 - acc: 0.8225 - val_loss: 1.6224 - val_acc: 0.4846
#
# Epoch 00044: val_loss did not improve from 1.45768
# Epoch 45/50
# 50000/50000 [==============================] - 2s 33us/step - loss: 0.5741 - acc: 0.8288 - val_loss: 1.6376 - val_acc: 0.4873
#
# Epoch 00045: val_loss did not improve from 1.45768
# Epoch 46/50
# 50000/50000 [==============================] - 2s 33us/step - loss: 0.5569 - acc: 0.8362 - val_loss: 1.6592 - val_acc: 0.4902
#
# Epoch 00046: val_loss did not improve from 1.45768
# Epoch 47/50
# 50000/50000 [==============================] - 2s 34us/step - loss: 0.5410 - acc: 0.8430 - val_loss: 1.6688 - val_acc: 0.4858
#
# Epoch 00047: val_loss did not improve from 1.45768
# Epoch 48/50
# 50000/50000 [==============================] - 2s 33us/step - loss: 0.5238 - acc: 0.8484 - val_loss: 1.6702 - val_acc: 0.4884
#
# Epoch 00048: val_loss did not improve from 1.45768
# Epoch 49/50
# 50000/50000 [==============================] - 2s 33us/step - loss: 0.5073 - acc: 0.8546 - val_loss: 1.6653 - val_acc: 0.4888
#
# Epoch 00049: val_loss did not improve from 1.45768
# Epoch 50/50
# 50000/50000 [==============================] - 2s 33us/step - loss: 0.4893 - acc: 0.8627 - val_loss: 1.6895 - val_acc: 0.4858
#
# Epoch 00050: val_loss did not improve from 1.45768
# 10000/10000 [==============================] - 1s 56us/step

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(range(len(train_loss)), train_loss, label="train loss")
plt.plot(range(len(valid_loss)), valid_loss, label="valid loss")
plt.hlines(y=loss_loadback, xmin=0, xmax=len(train_loss), colors='r', linestyles='--')
plt.legend()
plt.title("Loss")
plt.show()

plt.plot(range(len(train_acc)), train_acc, label="train accuracy")
plt.plot(range(len(valid_acc)), valid_acc, label="valid accuracy")
plt.hlines(y=acc_loadback, xmin=0, xmax=len(train_loss), colors='r', linestyles='--')
plt.legend()
plt.title("Accuracy")
plt.show()
